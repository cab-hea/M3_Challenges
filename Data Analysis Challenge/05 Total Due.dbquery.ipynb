-- %%
/*
Commandes et revenus totaux :
Calculez le montant total des revenus générés par toutes les commandes
(TotalDue).
(Table : SalesOrderHeader)
*/

Select sum(soh.TotalDue) as TotalDue
from saleslt.salesorderheader as SOH ;
