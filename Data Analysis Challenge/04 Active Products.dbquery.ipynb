-- %%
/* Récupérez tous les produits encore en vente (SellEndDate IS NULL) et triés par
leur prix décroissant.
(Table : Product) */

select * 
from saleslt.product 
where SellEndDate is null 
order by ListPrice desc ;
