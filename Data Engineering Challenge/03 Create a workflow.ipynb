# %% [markdown]
# resources:
#   jobs:
#     Load_Lakehouse:
#       name: Load Lakehouse
#       tasks:
#         - task_key: Load_Bronze
#           notebook_task:
#             notebook_path: /Workspace/Users/claire-anne.berger@he-arc.ch/m3/02 Data
#               engineering/11_ETL_Bronze_SQL
#             source: WORKSPACE
#           environment_key: Default
#         - task_key: Load_Silver
#           depends_on:
#             - task_key: Load_Bronze
#           notebook_task:
#             notebook_path: /Workspace/Users/claire-anne.berger@he-arc.ch/m3/02 Data
#               engineering/21_ETL_Silver_SQL
#             source: WORKSPACE
#           environment_key: Default
#       queue:
#         enabled: true
#       environments:
#         - environment_key: Default
#           spec:
#             environment_version: "4"
#       performance_target: PERFORMANCE_OPTIMIZED

# %% [markdown]
# ![](path)

# %% [markdown]
# ![](path)

# %% [markdown]
# ![](path)

# %% [markdown]
# ![]("C:\Users\ca-hea\Pictures\CAS IA M3\DEC 03 Workflow.jpg")

# %% [markdown]
# ![](path)
